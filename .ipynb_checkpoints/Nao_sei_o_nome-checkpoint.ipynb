# %% [markdown]
# # Projeto ATD
# ## 2ºsemestre 2020/2021
# ### FCTUC - DEI
# ### Membros:
# * Joel Oliveira
# * Tomás Mendes

# %%
import numpy as np
from sympy import *
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
sns.set_style("whitegrid")

# %% [markdown]
# ## Ler dados do acelerómetro para variável
# ### (1 variável / experiência )
# ###### userA_expB

# %%
user1_1 = pd.DataFrame(data=np.loadtxt("DataPL/acc_exp01_user01.txt"), columns=['X','Y','Z'])
user1_2 = pd.DataFrame(data=np.loadtxt("DataPL/acc_exp02_user01.txt"), columns=['X','Y','Z'])
user2_1 = pd.DataFrame(data=np.loadtxt("DataPL/acc_exp03_user02.txt"), columns=['X','Y','Z'])
user2_2 = pd.DataFrame(data=np.loadtxt("DataPL/acc_exp04_user02.txt"), columns=['X','Y','Z'])
user3_1 = pd.DataFrame(data=np.loadtxt("DataPL/acc_exp05_user03.txt"), columns=['X','Y','Z'])
user3_2 = pd.DataFrame(data=np.loadtxt("DataPL/acc_exp06_user03.txt"), columns=['X','Y','Z'])
user4_1 = pd.DataFrame(data=np.loadtxt("DataPL/acc_exp07_user04.txt"), columns=['X','Y','Z'])
user4_2 = pd.DataFrame(data=np.loadtxt("DataPL/acc_exp08_user04.txt"), columns=['X','Y','Z'])

# %%
user1_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20598 entries, 0 to 20597
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X       20598 non-null  float64
#  1   Y       20598 non-null  float64
#  2   Z       20598 non-null  float64
# dtypes: float64(3)
# memory usage: 482.9 KB

# %%
user1_1.describe()
# Out:
#                   X             Y             Z
# count  20598.000000  20598.000000  20598.000000
# mean       0.880673     -0.101714      0.097088
# std        0.346449      0.340091      0.285555
# min       -0.647222     -1.209722     -0.676389
# 25%        0.805556     -0.285764     -0.081944
# 50%        0.981945     -0.202778     -0.004167
# 75%        1.019445     -0.031944      0.204167
# max        1.950000      1.036111      1.269444

# %%
freq = 50
T = 1/freq

# %% [markdown]
# ##### Juntar à estrutura com os dados a informação do tempo em minutos de cada experiência

# %%
user1_1['Time (min)'] = np.arange(0, len(user1_1['X']) * T, T)/60
user1_2['Time (min)'] = np.arange(0, len(user1_2['X']) * T, T)/60 
user2_1['Time (min)'] = np.arange(0, len(user2_1['X']) * T, T)/60 
user2_2['Time (min)'] = np.arange(0, len(user2_2['X']) * T, T)/60 
user3_1['Time (min)'] = np.arange(0, len(user3_1['X']) * T, T)/60 
user3_2['Time (min)'] = np.arange(0, len(user3_2['X']) * T, T)/60 
user4_1['Time (min)'] = np.arange(0, len(user4_1['X']) * T, T)/60 
user4_2['Time (min)'] = np.arange(0, len(user4_2['X']) * T, T)/60

# %%
plt.figure(figsize=(14,8))
user = user1_1

plt.subplot(311)
plt.plot( minuts  , user['X'])
plt.xlabel("Time (min)")
plt.ylabel("ACC_X")
plt.title("Variação das Acelerações no Eixo X")

plt.subplot(312)
plt.plot( minuts  , user['Y'])
plt.xlabel("Time (min)")
plt.ylabel("ACC_Y")
plt.title("Variação das Acelerações no Eixo Y")

plt.subplot(313)
plt.plot( minuts  , user['Z'])
plt.xlabel("Time (min)")
plt.ylabel("ACC_Z")
plt.title("Variação das Acelerações no Eixo Z")

plt.tight_layout()

# %%
plt.figure(figsize=(14,8))
user = user1_1


plt.subplot(311)
sns.lineplot( x='Time (min)', y = 'X', data = user, size = 0.01, legend = False)
plt.xlabel("Time (min)")
plt.ylabel("ACC_X")
plt.xlim( (user['Time (min)'].min(), user['Time (min)'].max()) )
#plt.title("Variação das Acelerações no Eixo X")

plt.subplot(312)
sns.lineplot( x='Time (min)', y = 'Y', data = user, size = 0.01, legend = False)
plt.xlabel("Time (min)")
plt.ylabel("ACC_Y")
plt.xlim( (user['Time (min)'].min(), user['Time (min)'].max()) )
#plt.title("Variação das Acelerações no Eixo Y")

plt.subplot(313)
sns.lineplot( x='Time (min)', y = 'Z', data = user, size = 0.01, legend = False)
plt.xlabel("Time (min)")
plt.ylabel("ACC_Z")
plt.xlim( (user['Time (min)'].min(), user['Time (min)'].max()) )
#plt.title("Variação das Acelerações no Eixo Z")

plt.tight_layout()

# %%
plt.figure(figsize=(14,8))
user = user2_2

seg = np.arange(0, len(user['X']) * T, T)
minuts = seg/60

plt.subplot(311)
plt.plot( minuts  , user['X'])
plt.xlabel("Time (min)")
plt.ylabel("ACC_X")
plt.title("Variação das Acelerações no Eixo X")

plt.subplot(312)
plt.plot( minuts  , user['Y'])
plt.xlabel("Time (min)")
plt.ylabel("ACC_Y")
plt.title("Variação das Acelerações no Eixo Y")

plt.subplot(313)
plt.plot( minuts  , user['Z'])
plt.xlabel("Time (min)")
plt.ylabel("ACC_Z")
plt.title("Variação das Acelerações no Eixo Z")

plt.tight_layout()
