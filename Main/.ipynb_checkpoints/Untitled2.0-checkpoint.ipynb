# %%
import numpy as np
from sympy import *
import matplotlib.pyplot as plt
import pandas as pd
import math
from scipy import signal
import scipy as sy
from numpy.fft import fft, fftshift
import seaborn as sns
import matplotlib
from scipy.stats import entropy
from data import *
from functions_tomas import *
from funcoes_usadas import *

# %%
downintervals = [0.08, 0.44, 0.78,  1.2, 1.6, 1.9, 2.5,  3.2, 4.4, 5, 5.6]
upintervals = [0.39, 0.7, 1.1, 1.5, 1.9, 2.1, 2.8, 3.55, 4.7, 5.25, 5.8  ]

downlabels = ['STAND', 'SIT', 'STAND','LAY', 'SIT', 'LAY', 'W', 'W','W_D', 'W_D', 'W_D']
uplabels = ['STAND_SIT', 'SIT_STAND', 'STAND_LIE', 'LIE_SIT', 'SIT_LIE', 'LIE_STAND', 'W', 'W', 'W_U', 'W_U', 'W_U' ]

plot_with_labels(upintervals, downintervals, uplabels, downlabels, user1_1, 0)

# %% [markdown]
# # ATIVIDADES DINÂMICAS
#
# # --> WALKING <--

# %%
now = walks[0]
lim = 0.7
aux = get_dft(now, len(now),  False, lim, True, 'hann',True)

print( np.unique( np.round( np.abs( aux['Frequency (Hz)'][ (aux['X']>lim*aux['X']) & (np.abs(aux['Frequency (Hz)'])<=3) ] ), 8 ) ), end = '\t'*6)
print( np.unique( np.round( np.abs( aux['Frequency (Hz)'][ (aux['Y']>lim*aux['Y']) & (np.abs(aux['Frequency (Hz)'])<=3) ] ), 8 ) )  ,end = '\t'*6)
print( np.unique( np.round( np.abs( aux['Frequency (Hz)'][ (aux['Z']>lim*aux['Z']) & (np.abs(aux['Frequency (Hz)'])<=3) ] ), 8 ) )  ,end = '')

now = walks_d[0]
lim = 0.7
aux = get_dft(now, len(now),  False, lim, True, 'hann',True)

print( np.unique( np.round( np.abs( aux['Frequency (Hz)'][ (aux['X']>lim*aux['X']) & (np.abs(aux['Frequency (Hz)'])<=3) ] ), 8 ) ), end = '\t'*6)
print( np.unique( np.round( np.abs( aux['Frequency (Hz)'][ (aux['Y']>lim*aux['Y']) & (np.abs(aux['Frequency (Hz)'])<=3) ] ), 8 ) )  ,end = '\t'*6)
print( np.unique( np.round( np.abs( aux['Frequency (Hz)'][ (aux['Z']>lim*aux['Z']) & (np.abs(aux['Frequency (Hz)'])<=3) ] ), 8 ) )  ,end = '')

# %%
aux2 = get_amps(aux, len(aux))
aux2.describe()

# %%
now = walks_user[0][0]
lim = 0.6
aux = get_dft(now, len(now),  False, lim, True, 'rect',True)

#print( np.unique( np.round( np.abs( aux['Frequency (Hz)'][ (aux['X']>lim*aux['X']) & (np.abs(aux['Frequency (Hz)'])<=3) ] ), 8 ) ), end = '\n')
#print( np.unique( np.round( np.abs( aux['Frequency (Hz)'][ (aux['Y']>lim*aux['Y']) & (np.abs(aux['Frequency (Hz)'])<=3) ] ), 8 ) )  ,end = '\n')
print( np.unique( np.round( np.abs( aux['Frequency (Hz)'][ (aux['Z']>lim*aux['Z']) ] ), 8 ) )  ,end = '\n' + '-'*10)

now = walks_user[1][0]
lim = 0.7
aux = get_dft(now, len(now),  False, lim, True, 'rect',True)

#print( np.unique( np.round( np.abs( aux['Frequency (Hz)'][ (aux['X']>lim*aux['X']) & (np.abs(aux['Frequency (Hz)'])<=3) ] ), 8 ) ), end = '\n')
#print( np.unique( np.round( np.abs( aux['Frequency (Hz)'][ (aux['Y']>lim*aux['Y']) & (np.abs(aux['Frequency (Hz)'])<=3) ] ), 8 ) )  ,end = '\n')
print( np.unique( np.round( np.abs( aux['Frequency (Hz)'][ (aux['Z']>lim*aux['Z']) ] ), 8 ) )  ,end = '\n' + '-'*10)

now = walks_user[2][0]
lim = 0.7
aux = get_dft(now, len(now),  False, lim, True, 'rect',True)

#print( np.unique( np.round( np.abs( aux['Frequency (Hz)'][ (aux['X']>lim*aux['X']) & (np.abs(aux['Frequency (Hz)'])<=3) ] ), 8 ) ), end = '\n')
#print( np.unique( np.round( np.abs( aux['Frequency (Hz)'][ (aux['Y']>lim*aux['Y']) & (np.abs(aux['Frequency (Hz)'])<=3) ] ), 8 ) )  ,end = '\n')
print( np.unique( np.round( np.abs( aux['Frequency (Hz)'][ (aux['Z']>lim*aux['Z']) ] ), 8 ) )  ,end = '\n' + '-'*10)

now = walks_user[3][0]
lim = 0.7
aux = get_dft(now, len(now),  False, lim, True, 'rect',True)

#print( np.unique( np.round( np.abs( aux['Frequency (Hz)'][ (aux['X']>lim*aux['X']) & (np.abs(aux['Frequency (Hz)'])<=3) ] ), 8 ) ), end = '\n')
#print( np.unique( np.round( np.abs( aux['Frequency (Hz)'][ (aux['Y']>lim*aux['Y']) & (np.abs(aux['Frequency (Hz)'])<=3) ] ), 8 ) )  ,end = '\n')
print( np.unique( np.round( np.abs( aux['Frequency (Hz)'][ (aux['Z']>lim*aux['Z']) ] ), 8 ) )  ,end = '\n' + '-'*10)

# %%
now = walks_down_user[0][0]
lim = 0.7
aux = get_dft(now, len(now),  False, lim, True, 'rect',True)
print( np.unique( np.round( np.abs( aux['Frequency (Hz)'][ (aux['Z']>lim*aux['Z']) ] ), 8 ) )  ,end = '\n' + '-'*10)

now = walks_down_user[1][0]
lim = 0.7
aux = get_dft(now, len(now),  False, lim, True, 'rect',True)
print( np.unique( np.round( np.abs( aux['Frequency (Hz)'][ (aux['Z']>lim*aux['Z']) ] ), 8 ) )  ,end = '\n' + '-'*10)

now = walks_down_user[2][0]
lim = 0.7
aux = get_dft(now, len(now),  False, lim, True, 'rect',True)
print( np.unique( np.round( np.abs( aux['Frequency (Hz)'][ (aux['Z']>lim*aux['Z']) ] ), 8 ) )  ,end = '\n' + '-'*10)

now = walks_down_user[3][0]
lim = 0.7
aux = get_dft(now, len(now),  False, lim, True, 'rect',True)
print( np.unique( np.round( np.abs( aux['Frequency (Hz)'][ (aux['Z']>lim*aux['Z']) ] ), 8 ) )  ,end = '\n' + '-'*10)


#print( np.unique( np.round( np.abs( aux['Frequency (Hz)'][ (aux['X']>lim*aux['X']) & (np.abs(aux['Frequency (Hz)'])<=3) ] ), 8 ) ), end = '\t'*6)
#print( np.unique( np.round( np.abs( aux['Frequency (Hz)'][ (aux['Y']>lim*aux['Y']) & (np.abs(aux['Frequency (Hz)'])<=3) ] ), 8 ) )  ,end = '\t'*6)
#print( np.unique( np.round( np.abs( aux['Frequency (Hz)'][ (aux['Z']>lim*aux['Z']) & (np.abs(aux['Frequency (Hz)'])<=3) ] ), 8 ) )  ,end = '')

# %%
now = walks_up_user[0][0]
lim = 0.7
aux = get_dft(now, len(now),  False, lim, True, 'rect',True)
print( np.unique( np.round( np.abs( aux['Frequency (Hz)'][ (aux['Z']>lim*aux['Z']) ] ), 8 ) )  ,end = '\n' + '-'*10)

now = walks_up_user[1][0]
lim = 0.7
aux = get_dft(now, len(now),  False, lim, True, 'rect',True)
print( np.unique( np.round( np.abs( aux['Frequency (Hz)'][ (aux['Z']>lim*aux['Z']) ] ), 8 ) )  ,end = '\n' + '-'*10)

now = walks_up_user[2][0]
lim = 0.7
aux = get_dft(now, len(now),  False, lim, True, 'rect',True)
print( np.unique( np.round( np.abs( aux['Frequency (Hz)'][ (aux['Z']>lim*aux['Z']) ] ), 8 ) )  ,end = '\n' + '-'*10)

now = walks_up_user[3][0]
lim = 0.7
aux = get_dft(now, len(now),  False, lim, True, 'rect',True)
print( np.unique( np.round( np.abs( aux['Frequency (Hz)'][ (aux['Z']>lim*aux['Z']) ] ), 8 ) )  ,end = '\n' + '-'*10)

#print( np.unique( np.round( np.abs( aux['Frequency (Hz)'][ (aux['X']>lim*aux['X']) & (np.abs(aux['Frequency (Hz)'])<=3) ] ), 8 ) ), end = '\t'*6)
#print( np.unique( np.round( np.abs( aux['Frequency (Hz)'][ (aux['Y']>lim*aux['Y']) & (np.abs(aux['Frequency (Hz)'])<=3) ] ), 8 ) )  ,end = '\t'*6)
#print( np.unique( np.round( np.abs( aux['Frequency (Hz)'][ (aux['Z']>lim*aux['Z']) & (np.abs(aux['Frequency (Hz)'])<=3) ] ), 8 ) )  ,end = '')

# %%
aux2 = get_amps(aux, len(aux))
aux2.describe()

# %%
now = walks[2]
lim = 0.7
aux = get_dft(now, len(now),  False, lim, True, 'hann',True)

print( np.unique( np.round( np.abs( aux['Frequency (Hz)'][ (aux['X']>lim*aux['X']) & (np.abs(aux['Frequency (Hz)'])<=3) ] ), 8 ) ), end = '\t'*6)
print( np.unique( np.round( np.abs( aux['Frequency (Hz)'][ (aux['Y']>lim*aux['Y']) & (np.abs(aux['Frequency (Hz)'])<=3) ] ), 8 ) )  ,end = '\t'*6)
print( np.unique( np.round( np.abs( aux['Frequency (Hz)'][ (aux['Z']>lim*aux['Z']) & (np.abs(aux['Frequency (Hz)'])<=3) ] ), 8 ) )  ,end = '')

# %%
aux2 = get_amps(aux, len(aux))
aux2.describe()

# %%
now = walks[3]
lim = 0.6
aux = get_dft(now, len(now),  False, lim, True, 'hann',True)

print( np.unique( np.round( np.abs( aux['Frequency (Hz)'][ (aux['X']>lim*aux['X']) & (np.abs(aux['Frequency (Hz)'])<=3) ] ), 8 ) ), end = '\t'*6)
print( np.unique( np.round( np.abs( aux['Frequency (Hz)'][ (aux['Y']>lim*aux['Y']) & (np.abs(aux['Frequency (Hz)'])<=3) ] ), 8 ) )  ,end = '\t'*6)
print( np.unique( np.round( np.abs( aux['Frequency (Hz)'][ (aux['Z']>lim*aux['Z']) & (np.abs(aux['Frequency (Hz)'])<=3) ] ), 8 ) )  ,end = '')

# %%
aux2 = get_amps(aux, len(aux))
aux2.describe()

# %% [markdown]
# # --> WALKING_DOWN <--

# %%
now = down_walks[0]
lim = 0.7
aux = get_dft(now, len(now),  False, lim, True, 'hann',True)

print( np.unique( np.round( np.abs( aux['Frequency (Hz)'][ (aux['X']>lim*aux['X']) & (np.abs(aux['Frequency (Hz)'])<=3) ] ), 8 ) ), end = '\t'*6)
print( np.unique( np.round( np.abs( aux['Frequency (Hz)'][ (aux['Y']>lim*aux['Y']) & (np.abs(aux['Frequency (Hz)'])<=3) ] ), 8 ) )  ,end = '\t'*6)
print( np.unique( np.round( np.abs( aux['Frequency (Hz)'][ (aux['Z']>lim*aux['Z']) & (np.abs(aux['Frequency (Hz)'])<=3) ] ), 8 ) )  ,end = '')

# %%
aux2 = get_amps(aux, len(aux))

print( np.array(aux2['X'][np.where(aux2['X'])[0]]), end = '\t'*7)
print( np.array(aux2['Y'][np.where(aux2['Y'])[0]]) ,end = '\t'*2)
print( np.array(aux2['Z'][np.where(aux2['Z'])[0]])  ,end = '')

# %%
now = down_walks[1]
lim = 0.7
aux = get_dft(now, len(now),  False, lim, True, 'hann',True)

print( np.unique( np.round( np.abs( aux['Frequency (Hz)'][ (aux['X']>lim*aux['X']) & (np.abs(aux['Frequency (Hz)'])<=3) ] ), 8 ) ), end = '\t'*6)
print( np.unique( np.round( np.abs( aux['Frequency (Hz)'][ (aux['Y']>lim*aux['Y']) & (np.abs(aux['Frequency (Hz)'])<=3) ] ), 8 ) )  ,end = '\t'*6)
print( np.unique( np.round( np.abs( aux['Frequency (Hz)'][ (aux['Z']>lim*aux['Z']) & (np.abs(aux['Frequency (Hz)'])<=3) ] ), 8 ) )  ,end = '')

# %%
aux2 = get_amps(aux, len(aux))

print( np.array(aux2['X'][np.where(aux2['X'])[0]]), end = '\t'*8)
print( np.array(aux2['Y'][np.where(aux2['Y'])[0]]) ,end = '\t'*6)
print( np.array(aux2['Z'][np.where(aux2['Z'])[0]])  ,end = '')

# %%
now = down_walks_d[2]
lim = 0.7
aux = get_dft(now, len(now),  False, lim, True, 'hann')

print( np.unique( np.round( np.abs( aux['Frequency (Hz)'][ (aux['X']>lim*aux['X']) & (np.abs(aux['Frequency (Hz)'])<=2.5) ] ), 8 ) ), end = '\t'*5)
print( np.unique( np.round( np.abs( aux['Frequency (Hz)'][ (aux['Y']>lim*aux['Y']) & (np.abs(aux['Frequency (Hz)'])<=2.5) ] ), 8 ) )  ,end = '\t'*3)
print( np.unique( np.round( np.abs( aux['Frequency (Hz)'][ (aux['Z']>lim*aux['Z']) & (np.abs(aux['Frequency (Hz)'])<=2.5) ] ), 8 ) )  ,end = '')

# %%
aux2 = get_amps(aux, len(aux))

print( np.array(aux2['X'][np.where(aux2['X'])[0]]), end = '\t'*7)
print( np.array(aux2['Y'][np.where(aux2['Y'])[0]]) ,end = '\t'*2)
print( np.array(aux2['Z'][np.where(aux2['Z'])[0]])  ,end = '')

# %% [markdown]
# ## USER 1 EXPERIENCIA 1
# ### >>>WALKING<<<
# #### Apenas foram verificadas frequências com magnitude acima de 70% da máxima, e abaixo de 3Hz, para esta atividade
# <b> EIXO X </b> --> Para este voluntário, as frequências presentes nos eixos X rondam os valores $1.7$ a $1.9 Hz$. <br>
# <b> EIXO Y </b> --> Similarmente aos eixos X, as frequências presentes nos eixos Y rondam os valores $1.7$ a $1.9 Hz$ <br>
# <b> EIXO Z </b> --> Este eixo tem em todo o caso, para além de uma frequência similar à dos outros eixos, entre $1.7$ e $1.9$, uma frequência adicional a rondar valores no intervalo $[0.85, 0.90]$ <br>
# ##### Em todas as caminhadas, há duas frequências comuns aos 3 eixos, pelo que presumimos que estas sejam frequências correspondentes ao passo do utilizador em cada caminhada por ele feita.
# No caso são, respetivamente, $ \{1.78416168, 1.82719094 \} $ , $ \{ 1.83267322, 1.86066874 \} $ , $ \{1.80043279, 1.82793554 \} $ e $ \{1.75142083, 1.77738137\} $.
# Assim, uma estimativa para a frequência média do passo deste voluntário será:
# $
# \dfrac{(1.78416168 + 1.82719094 + 1.83267322 +  1.86066874 + 1.80043279 + 1.82793554 +  1.75142083 + 1.77738137)}8 = 1.8077331387500002 \ Hz
# $
# Em relação a amplitudes do sinal, as presentes nesta atividade são da ordem de grandeza $ 10^{-1} \ a \ 10^{-2} $, sendo que o valor mais alto se encontrou sempre nos eixos X
#
# ---------------------------------------
#
# ### >>>WALKING DOWNSTAIRS<<<
# #### Para esta experiência o limiar de frequências aceites foi diferente em cada momento, pois os valores estavam mais concentrados sem picos nalguns dos dados.
# #### EIXO X --> Nesta atividade os resultados deste voluntário já variaram um pouco em cada momento desta atividade. No primeiro momento as frequências estavam entre 1.5 e 1.6, aproximadamente, no segundo um pouco acima, mas dentro do espectável, 1.7 a 1.85, e no ultimo momento foram verificadas frequências significativas nos 2 intervalos
# #### EIXO Y --> Nos eixos Y as frequências foram similares as dos eixos X
# #### EIXO Z --> As frequências significativas sentidas nos eixos Z foram baixas, inferiores a 1 em todos os casos.
# ##### Similarmente à atividade walking, as frequências iguais presentes nos eixos foram selecionadas para a previsão do passo

# %%
import numpy as np
from sympy import *
import matplotlib.pyplot as plt
import pandas as pd
import math
from scipy import signal
import scipy as sy
from numpy.fft import fft, fftshift
import seaborn as sns
import matplotlib
from scipy.stats import entropy
from data import *
from functions_tomas import *
from funcoes_usadas import *

# %%
d = get_frequencies_from_activities(walks_user, 0.6, 'rect')
walk_user_freq = {'X':[d['X'].min(), d['X'].max()], 'Y': [d['Y'].min(), d['Y'].max()], 'Z':[d['Z'].min(), d['Z'].max()]}

d = get_frequencies_from_activities(walks_down_user, 0.8, 'rect')
walk_down_user_freq = {'X':[d['X'].min(), d['X'].max()], 'Y': [d['Y'].min(), d['Y'].max()], 'Z':[d['Z'].min(), d['Z'].max()]}

d = get_frequencies_from_activities(walks_up_user, 0.8, 'rect')
walk_up_user_freq = {'X':[d['X'].min(), d['X'].max()], 'Y': [d['Y'].min(), d['Y'].max()], 'Z':[d['Z'].min(), d['Z'].max()]}

d = get_frequencies_from_activities(stand_user, 0.8, 'rect')
stand_user_freq = {'X':[d['X'].min(), d['X'].max()], 'Y': [d['Y'].min(), d['Y'].max()], 'Z':[d['Z'].min(), d['Z'].max()]}

d = get_frequencies_from_activities(sit_user, 0.8, 'rect')
sit_user_freq = {'X':[d['X'].min(), d['X'].max()], 'Y': [d['Y'].min(), d['Y'].max()], 'Z':[d['Z'].min(), d['Z'].max()]}

d = get_frequencies_from_activities(lay_user, 0.8, 'rect')
lay_user_freq = {'X':[d['X'].min(), d['X'].max()], 'Y': [d['Y'].min(), d['Y'].max()], 'Z':[d['Z'].min(), d['Z'].max()]}

d = get_frequencies_from_activities(stand_sit_user, 0.8, 'rect')
stand_sit_user_freq = {'X':[d['X'].min(), d['X'].max()], 'Y': [d['Y'].min(), d['Y'].max()], 'Z':[d['Z'].min(), d['Z'].max()]}

d = get_frequencies_from_activities(sit_stand_user, 0.8, 'rect')
sit_stand_user_freq = {'X':[d['X'].min(), d['X'].max()], 'Y': [d['Y'].min(), d['Y'].max()], 'Z':[d['Z'].min(), d['Z'].max()]}

d = get_frequencies_from_activities(stand_lie_user, 0.8, 'rect')
stand_lie_user_freq = {'X':[d['X'].min(), d['X'].max()], 'Y': [d['Y'].min(), d['Y'].max()], 'Z':[d['Z'].min(), d['Z'].max()]}

d = get_frequencies_from_activities(lie_stand_user, 0.8, 'rect')
lie_stand_user_freq = {'X':[d['X'].min(), d['X'].max()], 'Y': [d['Y'].min(), d['Y'].max()], 'Z':[d['Z'].min(), d['Z'].max()]}

d = get_frequencies_from_activities(lie_stand_user, 0.8, 'rect')
lie_sit_user_freq = {'X':[d['X'].min(), d['X'].max()], 'Y': [d['Y'].min(), d['Y'].max()], 'Z':[d['Z'].min(), d['Z'].max()]}

d = get_frequencies_from_activities(sit_lie_user, 0.8, 'rect')
sit_lie_user_freq = {'X':[d['X'].min(), d['X'].max()], 'Y': [d['Y'].min(), d['Y'].max()], 'Z':[d['Z'].min(), d['Z'].max()]}

atividades = {}
atividades['walk'] = walk_user_freq
atividades['walk_down'] = walk_down_user_freq
atividades['walk_up'] = walk_up_user_freq
atividades['stand'] = stand_user_freq
atividades['lay'] = lay_user_freq
atividades['sit'] = sit_user_freq
atividades['stand_sit'] = stand_sit_user_freq
atividades['sit_stand'] = sit_stand_user_freq
atividades['stand_lie'] = stand_lie_user_freq
atividades['lie_stand'] = lie_stand_user_freq
atividades['lie_sit'] = lie_sit_user_freq
atividades['sit_lie'] = sit_lie_user_freq
# Out:
#               X         Y         Z
# count  2.000000  2.000000  5.000000
# mean   0.162953  0.120892  0.119704
# std    0.054916  0.021680  0.048978
# min    0.124122  0.105562  0.078319
# 25%    0.143538  0.113227  0.089783
# 50%    0.162953  0.120892  0.104512
# 75%    0.182369  0.128557  0.124122
# max    0.201785  0.136221  0.201785
#               X         Y         Z
# count  3.000000  4.000000  4.000000
# mean   0.116789  0.081281  0.117899
# std    0.033138  0.014504  0.027148
# min    0.095159  0.069848  0.095159
# 25%    0.097714  0.073448  0.098991
# 50%    0.100268  0.076428  0.110749
# 75%    0.127604  0.084261  0.129657
# max    0.154940  0.102422  0.154940
#               X         Y         Z
# count  2.000000  1.000000  4.000000
# mean   0.150040  0.126287  0.122636
# std    0.042388       NaN  0.042082
# min    0.120067  0.126287  0.079230
# 25%    0.135053  0.126287  0.103233
# 50%    0.150040  0.126287  0.115651
# 75%    0.165026  0.126287  0.135053
# ...

# %%
# %matplotlib
plt.ion()

unow = user1_1
times, freqs, cms = stft(unow, 200, 0.8, 5)
times = np.append([0], times)
for i in range(len(freqs)):
    freqs[i] = np.append([-1], freqs[i])
    
cms = np.append([0], cms)

i = 9
fig = plt.figure(figsize=(25,10))
plt.subplot(211)
for k in freqs:
    plt.plot(times, k, '*')
plt.axvspan(times[i], times[i+2], facecolor='g', alpha=0.5)
#print(cms)

plt.subplot(212)
x_axis = np.arange(0, len(unow['Z']) * (1/50), (1/50)) / 60
plt.plot(x_axis, unow['Z'], 'k', lw = 0.5)
t1 = times[::2]
t2 = times[1::2]
plt.vlines(t1, plt.ylim()[0] , plt.ylim()[1] , linestyle='dashed', color='red')
plt.vlines(t2, plt.ylim()[0] , plt.ylim()[1] , linestyle='dashed', color='blue')

a = int(t1[i]*60*50)
b = int(t2[i]*60*50)
plt.plot(x_axis[a:b], unow['Z'][a:b], 'g', lw = 1.5)
plt.axvspan(times[i], times[i+2], facecolor='g', alpha=0.5)
fig.tight_layout()
# Out:
# Using matplotlib backend: TkAgg
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-c02776679aab> in <module>
#      14 plt.subplot(211)
#      15 for k in freqs:
# ---> 16     plt.plot(times, k, '*')
#      17 plt.axvspan(times[i], times[i+2], facecolor='g', alpha=0.5)
#      18 #print(cms)
#
# c:\users\joelp\appdata\local\programs\python\python38\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2838 @_copy_docstring_and_deprecators(Axes.plot)
#    2839 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2840     return gca().plot(
#    2841         *args, scalex=scalex, scaley=scaley,
#    2842         **({"data": data} if data is not None else {}), **kwargs)
#
# ...

# %%
#print(atividades['stand'])
for i, j in enumerate(freqs[2]):
    print(f'i = {i}, Cm[i] = {cms[i]}')
    if cms[i] < 0.01:
        a = ['stand', 'sit', 'lay']
        for aa in a:
            if atividades[aa]['Z'][0] < j < atividades[aa]['Z'][1]:
                print(f'{j}Hz ({np.round(times[i], 3)}-{np.round(times[i+2],3)}s) in {aa}')
    else:
        a = ['walk', 'walk_down', 'walk_up', 'stand_sit', 'sit_stand', 'stand_lie', 'lie_stand', 'lie_sit', 'sit_lie']
        for aa in a:
            if atividades[aa]['Z'][0] < j < atividades[aa]['Z'][1]:
                print(f'{j}Hz ({np.round(times[i], 3)}-{np.round(times[i+2],3)}s) in {aa}')
                
    print('----------------')
# Out:
# i = 0, Cm[i] = 0.0
# ----------------
# i = 1, Cm[i] = 0.23827712719366378
# 0.43844221Hz (0.033-0.1s) in stand_sit
# 0.43844221Hz (0.033-0.1s) in sit_stand
# 0.43844221Hz (0.033-0.1s) in stand_lie
# 0.43844221Hz (0.033-0.1s) in lie_stand
# 0.43844221Hz (0.033-0.1s) in lie_sit
# 0.43844221Hz (0.033-0.1s) in sit_lie
# ----------------
# i = 2, Cm[i] = 0.06423714969897826
# 0.31344221Hz (0.067-0.133s) in stand_sit
# 0.31344221Hz (0.067-0.133s) in sit_stand
# 0.31344221Hz (0.067-0.133s) in stand_lie
# 0.31344221Hz (0.067-0.133s) in lie_stand
# 0.31344221Hz (0.067-0.133s) in lie_sit
# 0.31344221Hz (0.067-0.133s) in sit_lie
# ----------------
# i = 3, Cm[i] = 0.006918843184751817
# 2.1928392Hz (0.1-0.167s) in sit
# 2.1928392Hz (0.1-0.167s) in lay
# ----------------
# i = 4, Cm[i] = 0.0023352394489397554
# 0.68907035Hz (0.133-0.2s) in stand
# 0.68907035Hz (0.133-0.2s) in sit
# 0.68907035Hz (0.133-0.2s) in lay
# ----------------
# i = 5, Cm[i] = 0.0022846740752570423
# ...

# %%
fs = 50
miniNs=300
overlap=miniNs/2
deltaf = fs/miniNs
print('Resolução em frequência por janela [Hz]:\n', deltaf)
deltat = (miniNs/50)-(overlap/50)
print(deltat)
# Out:
# Resolução em frequência por janela [Hz]:
#  0.16666666666666666
# 3.0

# %%
stand_to_lie.plot(x = 'Time (min)', y = 'Z')

# %%
stand_to_lie_d.plot(x = 'Time (min)', y = 'Z')

# %%
stands_d[0].plot('Time (min)', 'Z', figsize=(20,4))
print( stands_d[1]['Z'].mean(), stands_d[1]['Z'].std(), sep = '\n')

# %%
set_between_std(stands_d[0])
stands_d[0].plot('Time (min)', 'Z', figsize=(20,4))
print( stands_d[0]['Z'].mean(), stands_d[0]['Z'].std(), sep = '\n')

# %%
#set_between_std(sits_d[1])
sits_d[1].plot('Time (min)', 'Z', figsize=(20,4))
print( sits_d[1]['Z'].mean(), sits_d[1]['Z'].std(), sep = '\n')

# %%
set_between_std(sits_d[1])
sits_d[1].plot('Time (min)', 'Z', figsize=(20,4))
print( sits_d[1]['Z'].mean(), sits_d[1]['Z'].std(), sep = '\n')

# %%
lays_d[0].plot('Time (min)', 'Z', figsize=(20,4))
print( lays_d[0]['Z'].mean(), lays_d[0]['Z'].std(), sep = '\n')

# %%
set_between_std(lays_d[0])
lays_d[0].plot('Time (min)', 'Z', figsize=(20,4))
print( lays_d[0]['Z'].mean(), lays_d[0]['Z'].std(), sep = '\n')

# %%
sit_values = np.array([])
for i in sit_user_nd:
    for j in i:
        sit_values = np.append(sit_values, np.mean(np.array(j['Z'])))

# %%
sit_values.mean()

# %%
sit_values.std()

# %%
print( '[', sit_values.mean() - sit_values.std()/2,',', sit_values.mean() + sit_values.std()/2, ']')

# %%
stand_values = np.array([])
for i in stand_user_nd:
    for j in i:
        stand_values = np.append(stand_values, np.mean(np.array(j['Z'])))

# %%
stand_values.mean()

# %%
stand_values.std()

# %%
print( '[', stand_values.mean() - stand_values.std()/2,',', stand_values.mean() + stand_values.std()/2, ']')

# %%
lay_values = np.array([])
for i in lay_user_nd:
    for j in i:
        lay_values = np.append(lay_values, np.mean(np.array(j['Z'])))

# %%
lay_values.mean()

# %%
lay_values.std()

# %%
print( '[', lay_values.mean() - lay_values.std()/2,',', lay_values.mean() + lay_values.std()/2, ']')

# %%
get_frequencies_from_activities(stand_user, 0.7, 'hann').describe()
# Out:
#                X         Y          Z
# count  34.000000  2.000000  38.000000
# mean    0.000250  0.002604   0.000402
# std     0.000029  0.000128   0.000485
# min     0.000214  0.002513   0.000214
# 25%     0.000227  0.002559   0.000229
# 50%     0.000239  0.002604   0.000243
# 75%     0.000271  0.002649   0.000288
# max     0.000306  0.002695   0.002147
#               X         Y         Z
# count  2.000000  1.000000  4.000000
# mean   0.000963  0.001933  0.001779
# std    0.000655       NaN  0.001280
# min    0.000500  0.001933  0.000500
# 25%    0.000731  0.001933  0.001194
# 50%    0.000963  0.001933  0.001534
# 75%    0.001194  0.001933  0.002119
# max    0.001426  0.001933  0.003550
#               X         Y         Z
# count  3.000000  3.000000  6.000000
# mean   0.000509  0.001842  0.000927
# std    0.000080  0.000062  0.000482
# min    0.000417  0.001778  0.000417
# 25%    0.000481  0.001812  0.000550
# 50%    0.000546  0.001847  0.000843
# ...

# %%
get_frequencies_from_activities(walks_user, 0.7, 'hann').describe()
# Out:
#               X         Y         Z
# count  2.000000  3.000000  5.000000
# mean   0.102683  0.065687  0.075710
# std    0.019644  0.008248  0.027068
# min    0.088792  0.058213  0.051782
# 25%    0.095737  0.061263  0.054926
# 50%    0.102683  0.064312  0.066477
# 75%    0.109628  0.069424  0.088792
# max    0.116573  0.074536  0.116573
#               X         Y         Z
# count  1.000000  3.000000  3.000000
# mean   0.111759  0.060010  0.077817
# std         NaN  0.010985  0.029653
# min    0.111759  0.051951  0.056941
# 25%    0.111759  0.053754  0.060846
# 50%    0.111759  0.055556  0.064751
# 75%    0.111759  0.064039  0.088255
# max    0.111759  0.072523  0.111759
#               X         Y         Z
# count  2.000000  1.000000  5.000000
# mean   0.099546  0.078052  0.073749
# std    0.019885       NaN  0.026159
# min    0.085485  0.078052  0.049246
# 25%    0.092516  0.078052  0.055543
# 50%    0.099546  0.078052  0.064863
# 75%    0.106576  0.078052  0.085485
# ...

# %%
get_frequencies_from_activities(walks_up_user, 0.7, 'hann').describe()

# %%
def stft(user, janela, percent):
    miniNs = janela
    overlap = miniNs//2

    fs = 50
    if miniNs%2==0:
        f = np.linspace( -fs/2, fs/2 - fs/2/miniNs, miniNs) 
    else:
        f = np.linspace( -fs/2 + fs/2/miniNs, fs/2 - fs/2/miniNs, miniNs)
    
    flag_max_freq = 5
    freqs = [np.array([])] * flag_max_freq
    window = np.hanning(miniNs)
    times = np.array([])
    cms_max = np.array([])
    
    N = len(user['Z'])
    

    for i in range(0, N-miniNs + 1, miniNs - overlap):
        Cms = np.array([])
        seccao = signal.detrend(user['Z'][i:i+miniNs])
        dft = np.abs(fftshift(fft(seccao)))
        
        for j in range(len(dft[f>=0])):
            if f[f>=0][j]==0:
                Cms = np.append(Cms, [dft[f>=0][j]/miniNs])
            else:
                Cms = np.append(Cms, [dft[f>=0][j]*2/miniNs])

        cms_max = np.append( cms_max, [max(Cms)])
        #c_max = max(dft)*(2 if np.any(f[dft==max(dft)]!=0) else 1)/miniNs
        #print(c_max)

        dft = np.abs(fftshift(fft(seccao*window)))
        dft[dft<np.max(dft)*percent] = 0
        
        
        
        for j in range(len(np.unique(np.round(np.abs(f[ dft>0 ][ f[dft>0]<=2.5 ]), 8)))):
            if j == flag_max_freq:
                break
            else:
                freqs[j] = np.append( freqs[j], np.unique(np.round(np.abs(f[dft>0][f[dft>0]<=2.5]), 8))[j] )
        
        max_len = max(map(lambda x: len(x), freqs))
        for j in range(len(freqs)):
            while len(freqs[j]) < max_len:
                freqs[j] = np.append(freqs[j], [-1])
             
        
        times = np.append(times, user['Time (min)'][(2*i+miniNs)//2])

    return times, freqs, cms_max

# %%
stft(walks_user1_1[0], 100, 0.7)
# Out:
# (array([2.51533333, 2.532     , 2.54866667, 2.56533333, 2.582     ,
#         2.59866667, 2.61533333, 2.632     , 2.64866667, 2.66533333]),
#  [array([0.37626263, 0.37626263, 0.37626263, 0.37626263, 0.37626263,
#          0.37626263, 0.37626263, 0.37626263, 0.37626263, 0.37626263]),
#   array([0.62878788, 0.62878788, 0.62878788, 0.62878788, 0.62878788,
#          0.62878788, 0.62878788, 0.62878788, 0.62878788, 0.62878788]),
#   array([0.87878788, 0.87878788, 0.87878788, 0.87878788, 0.87878788,
#          0.87878788, 0.87878788, 0.87878788, 0.87878788, 0.87878788]),
#   array([1.13131313, 1.13131313, 1.13131313, 1.13131313, 1.13131313,
#          1.13131313, 1.13131313, 1.13131313, 1.13131313, 1.13131313]),
#   array([-1.        ,  1.38131313, -1.        ,  1.88383838,  1.88383838,
#           1.88383838,  1.88383838, -1.        , -1.        ,  1.38131313])],
#  array([0.11379195, 0.10578671, 0.11416801, 0.13632008, 0.1492547 ,
# ...

# %%
int_sit = [ 0.12474575062190275 , 0.2588505323953851 ]
int_stand = [ 0.033557512938152595 , 0.11865090798603453 ]
int_lay = [ 0.3363668429374793 , 0.5798931288336633 ]

# %%
for i in stand_user_nd:
    for j in i:
        j = set_between_std(j)
        j.plot('Time (min)', 'Z')

# %%
for i in stand_user_nd:
    for j in i:
        j = set_between_std(j)
        print(int_stand[0]<=j['Z'].mean()<=int_stand[1])
# Out:
# True
# False
# False
# False
# False
# True
# False
# False
# True
# True
# False
# False
# False
# False
# False
# True

# %%
for i in sit_user_nd:
    for j in i:
        j = set_between_std(j)
        print(int_sit[0]<=j['Z'].mean()<=int_sit[1])
# Out:
# False
# False
# False
# True
# True
# False
# False
# True
# False
# False
# True
# False
# True
# False
# False
# False

# %%
for i in lay_user_nd:
    for j in i:
        j = set_between_std(j)
        print(int_lay[0]<=j['Z'].mean()<=int_lay[1])
# Out:
# True
# False
# True
# False
# False
# False
# False
# True
# False
# True
# True
# True
# True
# True
# False
# False
